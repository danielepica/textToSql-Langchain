# %%
from langchain_community.utilities import SQLDatabase

def connect_to_database(user: str, password: str,host: str, port: str, database: str):
    # Setup database
    db_postgres = f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}"
    return SQLDatabase.from_uri(db_postgres)
db = connect_to_database("postgres","password","localhost", "5432", "big_data")

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

chat = ChatGroq(
    temperature=0,
    model="llama3-70b-8192",
    api_key="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" # Optional if not set as an environment variable
)

# %%
from langchain_community.agent_toolkits import create_sql_agent
from langchain.agents import AgentType
agent_executor = create_sql_agent(chat, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True)

# %%
agent_executor.invoke("Quanti ordini sono stati effettuati da ciascun cliente?")
# Out:
# > Entering new SQL Agent Executor chain...
# Thought: I need to know the tables involved in this query and their schema.
#
# Action: sql_db_list_tables
# Action Input: sales_transactionLet's continue!
#
# Action: sql_db_schema
# Action Input: sales_transaction
# CREATE TABLE sales_transaction (
# 	transaction_number VARCHAR(255),
# 	date DATE,
# 	product_number VARCHAR(255),
# 	product_name VARCHAR(255),
# 	price NUMERIC(10, 2),
# 	quantity INTEGER,
# 	customer_number INTEGER,
# 	country VARCHAR(100)
# )
#
# /*
# 3 rows from sales_transaction table:
# transaction_number	date	product_number	product_name	price	quantity	customer_number	country
# 581482	2019-12-09	22485	Set Of 2 Wooden Market Crates	21.47	12	17490	United Kingdom
# 581475	2019-12-09	22596	Christmas Star Wish List Chalkboard	10.65	36	13069	United Kingdom
# 581475	2019-12-09	23235	Storage Tin Vintage Leaf	11.53	12	13069	United Kingdom
# ...
